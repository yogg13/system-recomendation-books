# %% [markdown]
# ### Books Recomendaton System

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
books = pd.read_csv('data/BX-Books.csv', sep= ";", on_bad_lines='skip', encoding='latin-1', low_memory=False)

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...

# %%
books.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %%
books = books[['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher', 'Image-URL-L']]

# %%
books.head(2)
# Out:
#          ISBN           Book-Title           Book-Author Year-Of-Publication  \
# 0  0195153448  Classical Mythology    Mark P. O. Morford                2002
# 1  0002005018         Clara Callan  Richard Bruce Wright                2001
#
#                  Publisher                                        Image-URL-L
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
# 1    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...

# %%
books.rename(columns={
    "Book-Title": "title",
    "Book-Author": "author",
    "Year-Of-Publication": "year",
    "Publisher": "publisher",
    "Image-URL-L": "img_url"
}, inplace = True)

# %%
books.head(2)
# Out:
#          ISBN                title                author  year  \
# 0  0195153448  Classical Mythology    Mark P. O. Morford  2002
# 1  0002005018         Clara Callan  Richard Bruce Wright  2001
#
#                  publisher                                            img_url
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
# 1    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...

# %%
users = pd.read_csv('data/BX-Users.csv', sep= ";", on_bad_lines='skip', encoding='latin-1', low_memory=False)

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
users.shape
# Out:
# (278858, 3)

# %%
ratings = pd.read_csv('data/BX-Book-Ratings.csv', sep= ";", on_bad_lines='skip', encoding='latin-1', low_memory=False)

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
ratings.rename(columns={
    "User-ID": "user_id",
    "Book-Rating": "rating" 
}, inplace=True)

# %%
ratings.head()
# Out:
#    user_id        ISBN  rating
# 0   276725  034545104X       0
# 1   276726  0155061224       5
# 2   276727  0446520802       0
# 3   276729  052165615X       3
# 4   276729  0521795028       6

# %%
ratings['user_id'].value_counts()
# Out:
# user_id
# 11676     13602
# 198711     7550
# 153662     6109
# 98391      5891
# 35859      5850
#           ...
# 116180        1
# 116166        1
# 116154        1
# 116137        1
# 276723        1
# Name: count, Length: 105283, dtype: int64

# %%
ratings['user_id'].unique().shape
# Out:
# (105283,)

# %%
i = ratings['user_id'].value_counts() > 300

# %%
i
# Out:
# user_id
# 11676      True
# 198711     True
# 153662     True
# 98391      True
# 35859      True
#           ...
# 116180    False
# 116166    False
# 116154    False
# 116137    False
# 276723    False
# Name: count, Length: 105283, dtype: bool

# %%
i[i].shape
# Out:
# (559,)

# %%
j = i[i].index

# %%
j
# Out:
# Index([ 11676, 198711, 153662,  98391,  35859, 212898, 278418,  76352, 110973,
#        235105,
#        ...
#        224646,  63394,  85701, 106816,  15418,  82511,  92853,  62895,  37567,
#        263163],
#       dtype='int64', name='user_id', length=559)

# %%
ratings = ratings[ratings['user_id'].isin(j)]

# %%
ratings
# Out:
#          user_id        ISBN  rating
# 1456      277427  002542730X      10
# 1457      277427  0026217457       0
# 1458      277427  003008685X       8
# 1459      277427  0030615321       0
# 1460      277427  0060002050       0
# ...          ...         ...     ...
# 1147612   275970  3829021860       0
# 1147613   275970  4770019572       0
# 1147614   275970   896086097       0
# 1147615   275970  9626340762       8
# 1147616   275970  9626344990       0
#
# [443362 rows x 3 columns]

# %%
ratings.shape
# Out:
# (443362, 3)

# %%
books.head(2)
# Out:
#          ISBN                title                author  year  \
# 0  0195153448  Classical Mythology    Mark P. O. Morford  2002
# 1  0002005018         Clara Callan  Richard Bruce Wright  2001
#
#                  publisher                                            img_url
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
# 1    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...

# %%
ratings_with_books = ratings.merge(books, on="ISBN")

# %%
ratings_with_books.head()
# Out:
#    user_id        ISBN  rating  \
# 0   277427  002542730X      10
# 1   277427  0026217457       0
# 2   277427  003008685X       8
# 3   277427  0030615321       0
# 4   277427  0060002050       0
#
#                                                title                 author  \
# 0  Politically Correct Bedtime Stories: Modern Ta...      James Finn Garner
# 1                 Vegetarian Times Complete Cookbook             Lucy  Moll
# 2                                           Pioneers  James Fenimore Cooper
# 3   Ask for May, Settle for June (A Doonesbury book)          G. B. Trudeau
# 4                  On a Wicked Dawn (Cynster Novels)      Stephanie Laurens
#
#    year                  publisher  \
# 0  1994  John Wiley &amp; Sons Inc
# 1  1995      John Wiley &amp; Sons
# 2  1974           Thomson Learning
# 3  1982        Henry Holt &amp; Co
# 4  2002                 Avon Books
#
#                                              img_url
# 0  http://images.amazon.com/images/P/002542730X.0...
# 1  http://images.amazon.com/images/P/0026217457.0...
# 2  http://images.amazon.com/images/P/003008685X.0...
# 3  http://images.amazon.com/images/P/0030615321.0...
# 4  http://images.amazon.com/images/P/0060002050.0...

# %%
ratings_with_books.shape
# Out:
# (410986, 8)

# %%
count_rating = ratings_with_books.groupby('title')['rating'].count().reset_index()

# %%
count_rating
# Out:
#                                                     title  rating
# 0        A Light in the Storm: The Civil War Diary of ...       2
# 1                                   Always Have Popsicles       1
# 2                    Apple Magic (The Collector's series)       1
# 3        Beyond IBM: Leadership Marketing and Finance ...       1
# 4        Clifford Visita El Hospital (Clifford El Gran...       1
# ...                                                   ...     ...
# 146000                             Ã?Â?ber das Fernsehen.       1
# 146001  Ã?Â?ber die Pflicht zum Ungehorsam gegen den S...       2
# 146002                                      Ã?Â?lpiraten.       1
# 146003                     Ã?Â?rger mit Produkt X. Roman.       1
# 146004                              Ã?Â?stlich der Berge.       1
#
# [146005 rows x 2 columns]

# %%
 count_rating.shape
# Out:
# (146005, 2)

# %%
count_rating.rename(columns={'rating': 'book_rating'}, inplace=True)

# %%
count_rating
# Out:
#                                                     title  book_rating
# 0        A Light in the Storm: The Civil War Diary of ...            2
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Beyond IBM: Leadership Marketing and Finance ...            1
# 4        Clifford Visita El Hospital (Clifford El Gran...            1
# ...                                                   ...          ...
# 146000                             Ã?Â?ber das Fernsehen.            1
# 146001  Ã?Â?ber die Pflicht zum Ungehorsam gegen den S...            2
# 146002                                      Ã?Â?lpiraten.            1
# 146003                     Ã?Â?rger mit Produkt X. Roman.            1
# 146004                              Ã?Â?stlich der Berge.            1
#
# [146005 rows x 2 columns]

# %%
rating_final = ratings_with_books.merge(count_rating, on='title')

# %%
rating_final.head(2)
# Out:
#    user_id        ISBN  rating  \
# 0   277427  002542730X      10
# 1   277427  0026217457       0
#
#                                                title             author  year  \
# 0  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 1                 Vegetarian Times Complete Cookbook         Lucy  Moll  1995
#
#                    publisher  \
# 0  John Wiley &amp; Sons Inc
# 1      John Wiley &amp; Sons
#
#                                              img_url  book_rating
# 0  http://images.amazon.com/images/P/002542730X.0...           64
# 1  http://images.amazon.com/images/P/0026217457.0...            6

# %%
rating_final.shape
# Out:
# (410986, 9)

# %%
rating_final[rating_final['book_rating']>=50]
# Out:
#         user_id        ISBN  rating  \
# 0        277427  002542730X      10
# 13       277427  0060930535       0
# 15       277427  0060934417       0
# 18       277427  0061009059       9
# 24       277427  006440188X       0
# ...         ...         ...     ...
# 410599   275970  0743412028       0
# 410688   275970  0804111359       0
# 410689   275970  0804117683       0
# 410820   275970  1400031354       0
# 410933   275970  1586210661       9
#
#                                                     title  \
# 0       Politically Correct Bedtime Stories: Modern Ta...
# 13                          The Poisonwood Bible: A Novel
# 15                                     Bel Canto: A Novel
# 18      One for the Money (Stephanie Plum Novels (Pape...
# 24                                      The Secret Garden
# ...                                                   ...
# 410599                                     Pay It Forward
# 410688                                     Secret History
# 410689                                                Moo
# 410820  Tears of the Giraffe (No.1 Ladies Detective Ag...
# 410933                             Me Talk Pretty One Day
#
#                          author  year                  publisher  \
# 0             James Finn Garner  1994  John Wiley &amp; Sons Inc
# 13           Barbara Kingsolver  1999                  Perennial
# 15                 Ann Patchett  2002                  Perennial
# 18              Janet Evanovich  1995                HarperTorch
# 24      Frances Hodgson Burnett  1998               HarperTrophy
# ...                         ...   ...                        ...
# 410599      Catherine Ryan Hyde  2000                     Pocket
# 410688              DONNA TARTT  1993           Ballantine Books
# 410689              Jane Smiley  1998                  Ivy Books
# 410820   Alexander McCall Smith  2002                     Anchor
# 410933            David Sedaris  2001    Time Warner Audio Major
#
#                                                   img_url  book_rating
# 0       http://images.amazon.com/images/P/002542730X.0...           64
# 13      http://images.amazon.com/images/P/0060930535.0...          100
# 15      http://images.amazon.com/images/P/0060934417.0...           79
# 18      http://images.amazon.com/images/P/0061009059.0...           87
# 24      http://images.amazon.com/images/P/006440188X.0...           73
# ...                                                   ...          ...
# 410599  http://images.amazon.com/images/P/0743412028.0...           54
# 410688  http://images.amazon.com/images/P/0804111359.0...           61
# 410689  http://images.amazon.com/images/P/0804117683.0...           68
# 410820  http://images.amazon.com/images/P/1400031354.0...           67
# 410933  http://images.amazon.com/images/P/1586210661.0...          108
#
# [38223 rows x 9 columns]

# %%
rating_final = rating_final[rating_final['book_rating']>=50]

# %%
rating_final
# Out:
#         user_id        ISBN  rating  \
# 0        277427  002542730X      10
# 13       277427  0060930535       0
# 15       277427  0060934417       0
# 18       277427  0061009059       9
# 24       277427  006440188X       0
# ...         ...         ...     ...
# 410599   275970  0743412028       0
# 410688   275970  0804111359       0
# 410689   275970  0804117683       0
# 410820   275970  1400031354       0
# 410933   275970  1586210661       9
#
#                                                     title  \
# 0       Politically Correct Bedtime Stories: Modern Ta...
# 13                          The Poisonwood Bible: A Novel
# 15                                     Bel Canto: A Novel
# 18      One for the Money (Stephanie Plum Novels (Pape...
# 24                                      The Secret Garden
# ...                                                   ...
# 410599                                     Pay It Forward
# 410688                                     Secret History
# 410689                                                Moo
# 410820  Tears of the Giraffe (No.1 Ladies Detective Ag...
# 410933                             Me Talk Pretty One Day
#
#                          author  year                  publisher  \
# 0             James Finn Garner  1994  John Wiley &amp; Sons Inc
# 13           Barbara Kingsolver  1999                  Perennial
# 15                 Ann Patchett  2002                  Perennial
# 18              Janet Evanovich  1995                HarperTorch
# 24      Frances Hodgson Burnett  1998               HarperTrophy
# ...                         ...   ...                        ...
# 410599      Catherine Ryan Hyde  2000                     Pocket
# 410688              DONNA TARTT  1993           Ballantine Books
# 410689              Jane Smiley  1998                  Ivy Books
# 410820   Alexander McCall Smith  2002                     Anchor
# 410933            David Sedaris  2001    Time Warner Audio Major
#
#                                                   img_url  book_rating
# 0       http://images.amazon.com/images/P/002542730X.0...           64
# 13      http://images.amazon.com/images/P/0060930535.0...          100
# 15      http://images.amazon.com/images/P/0060934417.0...           79
# 18      http://images.amazon.com/images/P/0061009059.0...           87
# 24      http://images.amazon.com/images/P/006440188X.0...           73
# ...                                                   ...          ...
# 410599  http://images.amazon.com/images/P/0743412028.0...           54
# 410688  http://images.amazon.com/images/P/0804111359.0...           61
# 410689  http://images.amazon.com/images/P/0804117683.0...           68
# 410820  http://images.amazon.com/images/P/1400031354.0...           67
# 410933  http://images.amazon.com/images/P/1586210661.0...          108
#
# [38223 rows x 9 columns]

# %%
rating_final.sample(15)
# Out:
#         user_id        ISBN  rating  \
# 388705   258185  0385335482       0
# 404665   270713  0380002930      10
# 354944   236172  0316693006       0
# 289107   198711  051513628X       0
# 73984     43246  015100692X       0
# 148692    98741  0375707972       0
# 27239     14422  0385722206       0
# 26840     13552  051513628X       8
# 27728     14521  0440202043       0
# 242130   168064  0385722206       0
# 97779     60244  0553271636       0
# 400114   266865  0553272535       0
# 82361     52584  038529929X       0
# 337766   230522  0312978383       0
# 299136   204864  0345339681       0
#
#                                                     title             author  \
# 388705  Confessions of a Shopaholic (Summer Display Op...    SOPHIE KINSELLA
# 404665                                     Watership Down      Richard Adams
# 354944                                    Four Blind Mice    James Patterson
# 289107             Key of Light (Key Trilogy (Paperback))       Nora Roberts
# 73984                     The Crimson Petal and the White       Michel Faber
# 148692                                         The Reader   Bernhard Schlink
# 27239   Balzac and the Little Chinese Seamstress : A N...          DAI SIJIE
# 26840              Key of Light (Key Trilogy (Paperback))       Nora Roberts
# 27728                                       Shell Seekers  Rosamunde Pilcher
# 242130  Balzac and the Little Chinese Seamstress : A N...          DAI SIJIE
# 97779   D Is for Deadbeat (Kinsey Millhone Mysteries (...        Sue Grafton
# 400114                                              Night        Elie Wiesel
# 82361                                            Hannibal      Thomas Harris
# 337766                                    Winter Solstice  Rosamunde Pilcher
# 299136  The Hobbit : The Enchanting Prelude to The Lor...     J.R.R. TOLKIEN
#
#         year                publisher  \
# 388705  2001                    Delta
# 404665  1976                     Avon
# 354944  2002            Little, Brown
# 289107  2003               Jove Books
# 73984   2002                 Harcourt
# 148692  1999        Vintage Books USA
# 27239   2002                   Anchor
# 26840   2003               Jove Books
# 27728   1996                     Dell
# 242130  2002                   Anchor
# 97779   1988                   Bantam
# 400114  1982             Bantam Books
# 82361   1999            Del Sol Press
# 337766  2001  St. Martin's Paperbacks
# 299136  1986                  Del Rey
#
#                                                   img_url  book_rating
# 388705  http://images.amazon.com/images/P/0385335482.0...           95
# 404665  http://images.amazon.com/images/P/0380002930.0...           94
# 354944  http://images.amazon.com/images/P/0316693006.0...           65
# 289107  http://images.amazon.com/images/P/051513628X.0...           56
# 73984   http://images.amazon.com/images/P/015100692X.0...           79
# 148692  http://images.amazon.com/images/P/0375707972.0...          113
# 27239   http://images.amazon.com/images/P/0385722206.0...           81
# 26840   http://images.amazon.com/images/P/051513628X.0...           56
# 27728   http://images.amazon.com/images/P/0440202043.0...           62
# 242130  http://images.amazon.com/images/P/0385722206.0...           81
# 97779   http://images.amazon.com/images/P/0553271636.0...           67
# 400114  http://images.amazon.com/images/P/0553272535.0...           60
# 82361   http://images.amazon.com/images/P/038529929X.0...          144
# 337766  http://images.amazon.com/images/P/0312978383.0...           50
# 299136  http://images.amazon.com/images/P/0345339681.0...           63

# %%
rating_final.shape
# Out:
# (38223, 9)

# %%
rating_final.drop_duplicates(['title', 'user_id'], inplace=True)

# %%
rating_final.shape
# Out:
# (36666, 9)

# %%
book_pivot = rating_final.pivot_table(columns='user_id', index='title', values='rating')

# %%
book_pivot
# Out:
# user_id                                             254     2276    3363    \
# title
# 1984                                                   9.0     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN    10.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     0.0     NaN     NaN
# ...                                                    ...     ...     ...
# Without Remorse                                        NaN     NaN     NaN
# Wuthering Heights                                      NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     0.0
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# user_id                                             3757    4385    6251    \
# title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     NaN
# 4 Blondes                                              NaN     NaN     0.0
# A Bend in the Road                                     NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Without Remorse                                        NaN     NaN     0.0
# Wuthering Heights                                      NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     0.0
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# user_id                                             6543    6575    7158    \
# title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    9.0     NaN     0.0
# 2nd Chance                                             0.0     NaN     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     NaN     1.0     NaN
# ...                                                    ...     ...     ...
# Without Remorse                                        NaN     NaN     NaN
# Wuthering Heights                                      NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# user_id                                             7346    ...  270713  \
# title                                                       ...
# 1984                                                   8.0  ...     NaN
# 1st to Die: A Novel                                    NaN  ...     NaN
# 2nd Chance                                             NaN  ...     NaN
# 4 Blondes                                              NaN  ...     NaN
# A Bend in the Road                                     NaN  ...     NaN
# ...                                                    ...  ...     ...
# Without Remorse                                        NaN  ...     NaN
# Wuthering Heights                                      NaN  ...     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN  ...     NaN
# Zoya                                                   NaN  ...     NaN
# \O\" Is for Outlaw"                                    8.0  ...     NaN
#
# user_id                                             271284  273979  274004  \
# title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     NaN     0.0     NaN
# ...                                                    ...     ...     ...
# Without Remorse                                        0.0     NaN     NaN
# Wuthering Heights                                      NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   0.0     0.0     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# user_id                                             274061  274301  274308  \
# title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     0.0
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Without Remorse                                        NaN     NaN     NaN
# Wuthering Heights                                      NaN     NaN     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     8.0     NaN
#
# user_id                                             275970  277427  278418
# title
# 1984                                                   0.0     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Without Remorse                                        NaN     NaN     NaN
# Wuthering Heights                                      NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# [500 rows x 551 columns]

# %%
book_pivot.shape
# Out:
# (500, 551)

# %%
book_pivot.fillna(0, inplace=True)

# %%
book_pivot
# Out:
# user_id                                             254     2276    3363    \
# title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Without Remorse                                        0.0     0.0     0.0
# Wuthering Heights                                      0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# user_id                                             3757    4385    6251    \
# title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Without Remorse                                        0.0     0.0     0.0
# Wuthering Heights                                      0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# user_id                                             6543    6575    7158    \
# title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    9.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     1.0     0.0
# ...                                                    ...     ...     ...
# Without Remorse                                        0.0     0.0     0.0
# Wuthering Heights                                      0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# user_id                                             7346    ...  270713  \
# title                                                       ...
# 1984                                                   8.0  ...     0.0
# 1st to Die: A Novel                                    0.0  ...     0.0
# 2nd Chance                                             0.0  ...     0.0
# 4 Blondes                                              0.0  ...     0.0
# A Bend in the Road                                     0.0  ...     0.0
# ...                                                    ...  ...     ...
# Without Remorse                                        0.0  ...     0.0
# Wuthering Heights                                      0.0  ...     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0  ...     0.0
# Zoya                                                   0.0  ...     0.0
# \O\" Is for Outlaw"                                    8.0  ...     0.0
#
# user_id                                             271284  273979  274004  \
# title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Without Remorse                                        0.0     0.0     0.0
# Wuthering Heights                                      0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# user_id                                             274061  274301  274308  \
# title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Without Remorse                                        0.0     0.0     0.0
# Wuthering Heights                                      0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     8.0     0.0
#
# user_id                                             275970  277427  278418
# title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Without Remorse                                        0.0     0.0     0.0
# Wuthering Heights                                      0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# [500 rows x 551 columns]

# %%
from scipy.sparse import csr_matrix

# %%
book_sparse = csr_matrix(book_pivot)

# %%
book_sparse
# Out:
# <500x551 sparse matrix of type '<class 'numpy.float64'>'
# 	with 8458 stored elements in Compressed Sparse Row format>

# %%
from sklearn.neighbors import NearestNeighbors
model = NearestNeighbors(algorithm='brute')

# %%
model.fit(book_sparse)
# Out:
# NearestNeighbors(algorithm='brute')

# %%
distance, suggestion = model.kneighbors(book_pivot.iloc[237, :].values.reshape(1, -1), n_neighbors=6)

# %%
distance
# Out:
# array([[ 0.        , 32.48076354, 32.89376841, 33.22649545, 33.95585369,
#         34.16138171]])

# %%
suggestion
# Out:
# array([[237, 461, 133, 190,  95, 134]], dtype=int64)

# %%
for i in range(len(suggestion)):
    print(book_pivot.index[suggestion[i]])
# Out:
# Index(['Neverwhere',
#        'Tom Clancy's Op-Center (Tom Clancy's Op Center (Paperback))',
#        'Fortune's Rocks : A Novel', 'It Was on Fire When I Lay Down on It',
#        'Debt of Honor (Jack Ryan Novels)', 'Foucault's Pendulum'],
#       dtype='object', name='title')

# %%
book_pivot.index[3]
# Out:
# '4 Blondes'

# %%
book_pivot.index
# Out:
# Index(['1984', '1st to Die: A Novel', '2nd Chance', '4 Blondes',
#        'A Bend in the Road', 'A Case of Need',
#        'A Child Called \It\": One Child's Courage to Survive"',
#        'A Heartbreaking Work of Staggering Genius',
#        'A Is for Alibi (Kinsey Millhone Mysteries (Paperback))',
#        'A Man in Full',
#        ...
#        'Wicked: The Life and Times of the Wicked Witch of the West',
#        'Wild Animus', 'Winter Moon', 'Winter Solstice', 'Wish You Well',
#        'Without Remorse', 'Wuthering Heights',
#        'Zen and the Art of Motorcycle Maintenance: An Inquiry into Values',
#        'Zoya', '\O\" Is for Outlaw"'],
#       dtype='object', name='title', length=500)

# %%
book_name = book_pivot.index

# %%
import pickle
pickle.dump(model, open('artifacts/model.pkl', 'wb'))
pickle.dump(book_name, open('artifacts/book_name.pkl', 'wb'))
pickle.dump(rating_final, open('artifacts/rating_final.pkl', 'wb'))
pickle.dump(book_pivot, open('artifacts/book_pivot.pkl', 'wb'))

# %%
def book_recomendation(book_name):
    book_id = np.where(book_pivot.index == book_name)[0][0]
    distance, suggestion = model.kneighbors(book_pivot.iloc[book_id, :].values.reshape(1, -1), n_neighbors=6)

    for i in range(len(suggestion)):
        books = book_pivot.index[suggestion[i]]
        for j in books:
            print(j)

# %%
np.where(book_pivot.index == "1st to Die: A Novel")[0][0]
# Out:
# 1

# %%
book_name = 'Wicked: The Life and Times of the Wicked Witch of the West'
book_recomendation(book_name)
# Out:
# Wicked: The Life and Times of the Wicked Witch of the West
# Here on Earth
# Tom Clancy's Op-Center (Tom Clancy's Op Center (Paperback))
# The Reef
# Temptation
# Smilla's Sense of Snow
